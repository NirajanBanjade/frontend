# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
data=pd.read_csv("netflix.csv")

# %%
data
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10   15-01-22         10/6/2023
# 1           2           Premium               15   5/9/2021          22-06-23
# 2           3          Standard               12   28-02-23          27-06-23
# 3           4          Standard               12  10/7/2022          26-06-23
# 4           5             Basic               10   1/5/2023          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14   25-07-22         12/7/2023
# 2496     2497             Basic               15   4/8/2022          14-07-23
# 2497     2498          Standard               12   9/8/2022          15-07-23
# 2498     2499          Standard               13  12/8/2022         12/7/2023
# 2499     2500             Basic               15   13-08-22         12/7/2023
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User ID            2500 non-null   int64
#  1   Subscription Type  2500 non-null   object
#  2   Monthly Revenue    2500 non-null   int64
#  3   Join Date          2500 non-null   object
#  4   Last Payment Date  2500 non-null   object
#  5   Country            2500 non-null   object
#  6   Age                2500 non-null   int64
#  7   Gender             2500 non-null   object
#  8   Device             2500 non-null   object
#  9   Plan Duration      2500 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 195.4+ KB

# %%
data1=data.isnull().sum()

# %%
data1
# Out:
# User ID              0
# Subscription Type    0
# Monthly Revenue      0
# Join Date            0
# Last Payment Date    0
# Country              0
# Age                  0
# Gender               0
# Device               0
# Plan Duration        0
# dtype: int64

# %%
data.dtypes
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %%
data["Join Date"]=pd.to_datetime(data["Join Date"])
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_5744\2001355663.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data["Join Date"]=pd.to_datetime(data["Join Date"])

# %%
data
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 1           2           Premium               15 2021-05-09          22-06-23
# 2           3          Standard               12 2023-02-28          27-06-23
# 3           4          Standard               12 2022-10-07          26-06-23
# 4           5             Basic               10 2023-01-05          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2498     2499          Standard               13 2022-12-08         12/7/2023
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
data["Last Payment Date"]
# Out:
# 0       10/6/2023
# 1        22-06-23
# 2        27-06-23
# 3        26-06-23
# 4        28-06-23
#           ...
# 2495    12/7/2023
# 2496     14-07-23
# 2497     15-07-23
# 2498    12/7/2023
# 2499    12/7/2023
# Name: Last Payment Date, Length: 2500, dtype: object

# %%
data["Last Payment Date"]=pd.to_datetime(data["Last Payment Date"], format='%d-%b-%y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data["Last Payment Date"]=pd.to_datetime(data["Last Payment Date"], format='%d-%b-%y')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\tools\datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# ...

# %%
data

# %%
data["Last Payment Date"]=pd.to_datetime(data["Last Payment Date"],format="mixed")

# %%
data
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 1           2           Premium               15 2021-05-09          22-06-23
# 2           3          Standard               12 2023-02-28          27-06-23
# 3           4          Standard               12 2022-10-07          26-06-23
# 4           5             Basic               10 2023-01-05          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2498     2499          Standard               13 2022-12-08         12/7/2023
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
data

# %%
gender=data["Gender"].value_counts()

# %%
gender

# %%
# so the number of male and female using subscription are almost equal showing similar popularity....

# %%
data.duplicated().value_counts()

# %%
# so no any duplications in here

# %%
data["Subscription Type"].value_counts()

# %%
# So basic subscription has some edge over standard and premium subscriptions, which have some similar numbers

# %%
data.groupby('Subscription Type')['Device'].value_counts()

# %%
#This shows that the Devices laptop, smartphone and smart tv have equal popularities in each section of Basic , Premimum , and standard, showing lesser deviation with mean in each section and as a whole

# %%
data

# %%
country=data["Country"].value_counts()

# %%
country
# Out:
# Country
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: count, dtype: int64

# %%
# this shows that spain and US are the most popular countries with highest Netflix Users followed by Canada. other 7 countries are almost similar in terms of popularity.

# %%
data.groupby('Gender')['Age'].mean()
# Out:
# Gender
# Female    39.077963
# Male      38.510056
# Name: Age, dtype: float64

# %%
#Interestingly, The netflix craze can mostly be seen among adults(35+) more than childrens and teens.

# %%
plt.figure(figsize=(13,8))
plt.title("country sum")
plt.plot(country,'o')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 1           2           Premium               15 2021-05-09          22-06-23
# 2           3          Standard               12 2023-02-28          27-06-23
# 3           4          Standard               12 2022-10-07          26-06-23
# 4           5             Basic               10 2023-01-05          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2498     2499          Standard               13 2022-12-08         12/7/2023
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
#Data selcetd for observing among highest users in USA and Spain
selected=data[(data["Country"]=="United States") | (data["Country"]=="Spain") ]
print(selected)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 8           9          Standard               12 2022-10-20          23-06-23
# 10         11             Basic               10 2022-05-16          22-06-23
# 18         19           Premium               15 2023-02-15          23-06-23
# 20         21           Premium               15 2023-10-06          22-06-23
# ...       ...               ...              ...        ...               ...
# 2493     2494           Premium               12 2022-07-21          15-07-23
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
groupby("country")["Age"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 data[(data["Country"]=="United States") | (data["Country"]=="Spain") ].groupby("country")["Age"].value_counts()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
selected_rows = data[(data["Country"] == "United States") | (data["Country"] == "Spain")]
print(selected_rows)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 8           9          Standard               12 2022-10-20          23-06-23
# 10         11             Basic               10 2022-05-16          22-06-23
# 18         19           Premium               15 2023-02-15          23-06-23
# 20         21           Premium               15 2023-10-06          22-06-23
# ...       ...               ...              ...        ...               ...
# 2493     2494           Premium               12 2022-07-21          15-07-23
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
selected_rows.describe()
# Out:
#            User ID  Monthly Revenue                      Join Date         Age
# count   902.000000       902.000000                            902  902.000000
# mean   1361.567627        12.556541  2022-08-02 03:41:54.412416768   38.863636
# min       1.000000        10.000000            2022-01-07 00:00:00   26.000000
# 25%     814.500000        11.000000            2022-06-22 00:00:00   32.000000
# 50%    1374.000000        13.000000            2022-08-09 00:00:00   39.000000
# 75%    1940.500000        14.000000            2022-10-10 18:00:00   45.000000
# max    2500.000000        15.000000            2023-11-01 00:00:00   51.000000
# std     674.344106         1.695662                            NaN    7.348637

# %%
# this shows that most users in USA and SPain are working people (40+ age), which shows as a whole scenario of the world.
# This might be because teens and childrens cant afford monthly subscription of netflix.
# One predictive analysis drawn is netflix can give student discounts to teens and younsgster to attract larger engagement.

# %%
plt.bar(selected_rows["United States", "Spain"],selected_rows["Age"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('United States', 'Spain')
#
# ...

# %%
data["Age"].value_counts()
# Out:
# Age
# 39    116
# 30    116
# 28    115
# 31    115
# 41    114
# 47    111
# 37    107
# 35    105
# 29    104
# 40    103
# 42    102
# 48    101
# 46     99
# 36     99
# 49     97
# 43     94
# 33     93
# 51     93
# 32     92
# 45     89
# 38     89
# 34     88
# 27     87
# 44     86
# 50     84
# 26      1
# Name: count, dtype: int64

# %%
data
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15         10/6/2023
# 1           2           Premium               15 2021-05-09          22-06-23
# 2           3          Standard               12 2023-02-28          27-06-23
# 3           4          Standard               12 2022-10-07          26-06-23
# 4           5             Basic               10 2023-01-05          28-06-23
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25         12/7/2023
# 2496     2497             Basic               15 2022-04-08          14-07-23
# 2497     2498          Standard               12 2022-09-08          15-07-23
# 2498     2499          Standard               13 2022-12-08         12/7/2023
# 2499     2500             Basic               15 2022-08-13         12/7/2023
#
# ...

# %%
plt.figure(figsize=(8,8))
plt.plot(data["Country"],data.groupby("Country")["Age"].mean())
plt.show()
# Out:
#   Cell In[87], line 2
#     plt.plot(data["Country"],data.groupby("Country")["Age"].mean()]
#                                                                   ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '('

# %%
mean_age=data.groupby("Country")["Age"].mean()

# %%
mean_age
# Out:
# Country
# Australia         38.355191
# Brazil            38.327869
# Canada            38.697161
# France            39.109290
# Germany           39.038251
# Italy             38.551913
# Mexico            38.830601
# Spain             38.800443
# United Kingdom    39.191257
# United States     38.926829
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.plot(mean_age,color="red")
plt.show()

# %%
# Conclusion: 1. Apart from US and spain all other nations have comparatively lower engagement in netflix.
#             2. Mean age for all nations is same.(~38). This shows netflix is loosing its popularity among youths and teenagers.
#             
#
